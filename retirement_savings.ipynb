# %% [markdown]
# <a href="https://colab.research.google.com/github/pragathiz/investment-strategy/blob/main/retirement_savings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Description: retire within 10 years

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# get savings_rate
savings_rate = 0.50
# get yearly income
income = 300000
# get yearly expenses
expenses = income * (1 - savings_rate)
#get the interset rate from portfolio or assests
interest_rate = 0.08
#get the amount invested into portfolio or assests
investment = income - expenses
# calaculate expected annual returns
annual_return = investment * interest_rate
# get the current year
year = 2022
# get the withdrawal rate
withdrawal_rate = 0.04

# %%
# create an empty lists for the data set
Year = []
Yearly_Income = []
Yearly_Expenses = []
Yearly_Invested_Amount = []
Total_Invested_Amount = []
Annual_Returns = []

# %%
# append data to lists
Year.append(year)
Yearly_Income.append(income)
Yearly_Expenses.append(expenses)
Yearly_Invested_Amount.append(income - expenses)
Total_Invested_Amount.append(investment)
Annual_Returns.append(annual_return)

# %%
# create a variable to store the amount of years/rows invested
invested_years = 30
for i in range(0, invested_years -1):
  investment = (income - expenses) + annual_return + investment
  annual_return = investment * interest_rate
  #append the new data to the lists
  Year.append(year + i + 1)
  Yearly_Income.append(income)
  Yearly_Expenses.append(expenses)
  Yearly_Invested_Amount.append(income - expenses)
  Total_Invested_Amount.append(investment)
  Annual_Returns.append(annual_return)

# %%
# create the data set
df = pd.DataFrame()
df['Year'] = Year
df['Yearly_income'] = Yearly_Income
df['Yearly_Expenses'] = Yearly_Expenses
df['Yearly_Invested_Amount'] = Yearly_Invested_Amount
df['Total_Invested_Amount'] = Total_Invested_Amount
df['Annual_Returns'] = Annual_Returns
Yearly_Withdrawal_Amount = np.array(Total_Invested_Amount) * withdrawal_rate
df['Yearly_Withdrawal_Amount'] = Yearly_Withdrawal_Amount

# %%
# show the data
df
# Out:
#     Year  Yearly_income  Yearly_Expenses  Yearly_Invested_Amount  \
# 0   2022         300000         150000.0                150000.0
# 1   2023         300000         150000.0                150000.0
# 2   2024         300000         150000.0                150000.0
# 3   2025         300000         150000.0                150000.0
# 4   2026         300000         150000.0                150000.0
# 5   2027         300000         150000.0                150000.0
# 6   2028         300000         150000.0                150000.0
# 7   2029         300000         150000.0                150000.0
# 8   2030         300000         150000.0                150000.0
# 9   2031         300000         150000.0                150000.0
# 10  2032         300000         150000.0                150000.0
# 11  2033         300000         150000.0                150000.0
# 12  2034         300000         150000.0                150000.0
# 13  2035         300000         150000.0                150000.0
# 14  2036         300000         150000.0                150000.0
# 15  2037         300000         150000.0                150000.0
# 16  2038         300000         150000.0                150000.0
# 17  2039         300000         150000.0                150000.0
# 18  2040         300000         150000.0                150000.0
# 19  2041         300000         150000.0                150000.0
# 20  2042         300000         150000.0                150000.0
# 21  2043         300000         150000.0                150000.0
# 22  2044         300000         150000.0                150000.0
# 23  2045         300000         150000.0                150000.0
# 24  2046         300000         150000.0                150000.0
# 25  2047         300000         150000.0                150000.0
# 26  2048         300000         150000.0                150000.0
# 27  2049         300000         150000.0                150000.0
# 28  2050         300000         150000.0                150000.0
# 29  2051         300000         150000.0                150000.0
#
#     Total_Invested_Amount  Annual_Returns  Yearly_Withdrawal_Amount
# 0            1.500000e+05    1.200000e+04               6000.000000
# 1            3.120000e+05    2.496000e+04              12480.000000
# 2            4.869600e+05    3.895680e+04              19478.400000
# 3            6.759168e+05    5.407334e+04              27036.672000
# 4            8.799901e+05    7.039921e+04              35199.605760
# 5            1.100389e+06    8.803115e+04              44015.574221
# 6            1.338421e+06    1.070736e+05              53536.820158
# 7            1.595494e+06    1.276395e+05              63819.765771
# 8            1.873134e+06    1.498507e+05              74925.347033
# 9            2.172984e+06    1.738387e+05              86919.374795
# 10           2.496823e+06    1.997458e+05              99872.924779
# 11           2.846569e+06    2.277255e+05             113862.758761
# 12           3.224294e+06    2.579436e+05             128971.779462
# 13           3.632238e+06    2.905790e+05             145289.521819
# 14           4.072817e+06    3.258254e+05             162912.683565
# 15           4.548642e+06    3.638914e+05             181945.698250
# 16           5.062534e+06    4.050027e+05             202501.354110
# 17           5.617537e+06    4.494029e+05             224701.462439
# 18           6.216939e+06    4.973552e+05             248677.579434
# 19           6.864295e+06    5.491436e+05             274571.785789
# 20           7.563438e+06    6.050751e+05             302537.528652
# 21           8.318513e+06    6.654811e+05             332740.530944
# 22           9.133994e+06    7.307195e+05             365359.773419
# 23           1.001471e+07    8.011771e+05             400588.555293
# 24           1.096589e+07    8.772713e+05             438635.639716
# 25           1.199316e+07    9.594530e+05             479726.490894
# 26           1.310262e+07    1.048209e+06             524104.610165
# 27           1.430082e+07    1.144066e+06             572032.978978
# 28           1.559489e+07    1.247591e+06             623795.617297
# 29           1.699248e+07    1.359399e+06             679699.266681

# %%
# visually show the data
plt.figure(figsize=(12,4))
plt.plot(df['Year'], df['Yearly_Expenses'], label = 'Yearly Expenses')
plt.plot(df['Year'], df['Yearly_Withdrawal_Amount'], label = 'Yearly Withdrawal Amount')
plt.title('Years Until Retirement')
plt.xlabel('Years')
plt.ylabel('INR (rupee)')
plt.xticks(df['Year'], rotation = 45)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# show the year/row where can live off of returns
df[df.Yearly_Expenses <= df.Yearly_Withdrawal_Amount].head(1)
# Out:
#     Year  Yearly_income  Yearly_Expenses  Yearly_Invested_Amount  \
# 14  2036         300000         150000.0                150000.0
#
#     Total_Invested_Amount  Annual_Returns  Yearly_Withdrawal_Amount
# 14           4.072817e+06    325825.36713             162912.683565
